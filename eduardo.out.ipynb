# %% [markdown]
# #
#
# # Conclusão
#
# Segue o que descobri sobre *minha consciência*.
#
# ## 2025
#
# 1.  Evito medir quando antecipo resultado ruim.
# 2.  Há situações que eu como para fugir de um desconforto.
# 3.  Leitura de mensagem no WhatsApp cria um novo bloco pensênico abrindo uma ligação a uma outra situação, consins e consiexs.
# 4.  Posso utilizar meu instrumento de pesquisa para registrar as situações relacionadas às sinaléticas para processamento posterior.
